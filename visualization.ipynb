# %% [markdown]
# # ResNet18(DynamicConv2D) loss, accuracy plot

# %%
import matplotlib.pyplot as plt

# Data setup
epochs = list(range(1, 31))
train_loss = [
    3.815005, 3.574237, 3.447280, 3.358057, 3.259555, 3.163172, 3.056617,
    2.973447, 2.888124, 2.816193, 2.749706, 2.699769, 2.644907, 2.589126,
    2.307866, 2.206610, 2.162020, 2.134986, 2.108404, 2.080119, 2.055221,
    2.042154, 2.020481, 2.000288, 1.986293, 1.964272, 1.948063, 1.933981,
    1.909190, 1.899953
]
validation_loss = [
    3.6338, 3.2164, 3.1540, 3.1935, 2.9393, 2.9253, 2.7748, 2.6882,
    2.4637, 2.4519, 2.3485, 2.2553, 2.2382, 2.2306, 1.7872, 1.7439,
    1.7071, 1.6612, 1.6375, 1.6263, 1.5996, 1.5681, 1.5497, 1.5115,
    1.5308, 1.5084, 1.4940, 1.4948, 1.5511, 1.4464
]
train_accuracy = [
    4.65, 8.56, 11.01, 12.66, 14.56, 16.72, 18.80, 20.49, 22.31, 23.84,
    25.36, 26.66, 27.68, 29.03, 35.57, 37.98, 39.25, 40.01, 40.49, 41.26,
    41.63, 42.23, 42.86, 43.47, 43.82, 44.10, 44.54, 44.85, 45.69, 45.89
]
validation_accuracy = [
    7.56, 15.11, 17.33, 15.56, 19.11, 20.44, 24.22, 24.89, 33.78, 29.56,
    33.33, 34.89, 38.89, 36.89, 49.33, 49.78, 49.78, 52.00, 52.67, 53.11,
    54.67, 54.00, 52.67, 55.33, 55.56, 55.11, 54.67, 53.56, 53.33, 57.33
]

# Creating plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot for Loss
ax1.plot(epochs, train_loss, label='Train Loss', color='cornflowerblue')
ax1.plot(epochs, validation_loss, label='Validation Loss', color='plum')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

# Plot for Accuracy
ax2.plot(epochs, train_accuracy, label='Train Accuracy', color='cornflowerblue')
ax2.plot(epochs, validation_accuracy, label='Validation Accuracy', color='plum')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

# plt.savefig('ResNet18(DynamicConv2D)_loss_accuracy_Plots.png', format='png', dpi=500)
# plt.close(fig)

plt.show()

# %% [markdown]
# # ResNet18 loss, accuracy plot

# %%
import matplotlib.pyplot as plt

# Data setup for the new training session
epochs = list(range(1, 31))
train_loss = [
    3.877870, 3.704179, 3.555709, 3.454451, 3.379856, 3.310372, 3.234963, 
    3.166563, 3.103732, 3.047830, 2.993371, 2.943518, 2.895362, 2.847849, 
    2.590407, 2.509489, 2.469996, 2.441964, 2.408815, 2.382054, 2.360101, 
    2.334501, 2.312828, 2.289448, 2.265477, 2.246955, 2.225855, 2.207562, 
    2.186268, 2.155499
]
validation_loss = [
    3.6710, 3.3713, 3.2584, 3.2095, 3.0533, 2.9895, 2.8385, 2.8339, 2.7557, 
    2.5937, 2.6488, 2.5565, 2.6567, 2.4016, 2.0810, 2.0338, 2.0419, 1.9982, 
    1.9786, 1.9419, 1.9068, 1.9285, 1.8508, 1.8967, 1.8178, 1.8269, 1.8445, 
    1.7112, 1.7073, 1.6484
]
train_accuracy = [
    3.60, 6.26, 8.92, 10.81, 12.32, 13.74, 15.42, 16.81, 18.05, 18.98, 20.30, 
    21.29, 22.41, 23.32, 29.28, 30.97, 32.06, 32.62, 33.35, 33.83, 34.51, 35.15, 
    35.54, 36.36, 36.93, 37.09, 37.80, 38.29, 38.94, 39.77
]
validation_accuracy = [
    8.22, 15.33, 14.67, 13.78, 21.56, 17.78, 23.33, 24.67, 26.22, 30.22, 31.33, 
    29.78, 26.00, 32.00, 42.00, 44.67, 43.33, 43.33, 44.89, 46.22, 46.00, 44.89, 
    48.67, 48.22, 47.78, 49.33, 45.78, 50.67, 48.89, 52.44
]

# Creating plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot for Loss
ax1.plot(epochs, train_loss, label='Train Loss', color='cornflowerblue')
ax1.plot(epochs, validation_loss, label='Validation Loss', color='plum')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

# Plot for Accuracy
ax2.plot(epochs, train_accuracy, label='Train Accuracy', color='cornflowerblue')
ax2.plot(epochs, validation_accuracy, label='Validation Accuracy', color='plum')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

# plt.savefig('ResNet18_loss_accuracy_Plots.png', format='png', dpi=500)
# plt.close(fig)

plt.show()

# %% [markdown]
# # mydesign 3-layer ResAttentionNet loss, accuracy plot

# %%
import matplotlib.pyplot as plt

# Epochs from 1 to 30
epochs = list(range(1, 31))

# Training and validation loss data
train_loss = [
    3.426510, 3.074935, 2.864124, 2.714202, 2.584586, 2.496285, 2.410968,
    2.355430, 2.289241, 2.250677, 2.209180, 2.171939, 2.137108, 2.117408,
    1.851230, 1.792091, 1.756889, 1.726704, 1.714737, 1.696301, 1.684013,
    1.673095, 1.663612, 1.645482, 1.642980, 1.633875, 1.621900, 1.618677,
    1.610855, 1.602591
]
validation_loss = [
    3.3898, 3.1524, 2.8747, 2.6667, 2.3101, 2.2628, 2.4805, 2.2627, 2.2934,
    2.1018, 2.0582, 1.9978, 1.9382, 1.9424, 1.4426, 1.4328, 1.4053, 1.4176,
    1.3635, 1.3617, 1.3775, 1.3359, 1.3335, 1.3234, 1.3364, 1.3598, 1.3229,
    1.3491, 1.2517, 1.2554
]

# Training and validation accuracy data
train_accuracy = [
    11.74, 18.77, 23.20, 26.43, 29.44, 31.54, 33.61, 34.98, 36.90, 37.55,
    38.64, 39.49, 40.66, 40.75, 47.90, 49.65, 50.60, 51.25, 51.56, 51.83,
    52.16, 52.53, 52.98, 52.99, 53.20, 53.50, 53.80, 53.82, 53.81, 54.38
]
validation_accuracy = [
    14.67, 18.44, 25.11, 25.78, 34.22, 36.44, 32.67, 37.11, 37.11, 41.33,
    43.11, 41.33, 44.00, 42.89, 60.44, 58.67, 60.22, 61.56, 62.00, 62.89,
    60.89, 63.11, 62.89, 62.67, 62.44, 63.11, 63.11, 64.89, 64.44, 63.78
]

# Creating the plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot for training and validation loss
ax1.plot(epochs, train_loss, 'cornflowerblue', label='Training Loss')
ax1.plot(epochs, validation_loss, 'plum', label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

# Plot for training and validation accuracy
ax2.plot(epochs, train_accuracy, 'cornflowerblue', label='Training Accuracy')
ax2.plot(epochs, validation_accuracy, 'plum', label='Validation Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

# plt.savefig('ResAttentionNet_loss_accuracy_Plots.png', format='png', dpi=500)
# plt.close(fig)

plt.show()

# %% [markdown]
# # ResNet34 loss, accuracy plot

# %%
import matplotlib.pyplot as plt

# Epochs from 1 to 30
epochs = list(range(1, 31))

# Training and validation loss data
train_loss = [
    3.858497, 3.552026, 3.295912, 3.115510, 2.983927, 2.885227, 2.804314, 
    2.686116, 2.608598, 2.521549, 2.453631, 2.401055, 2.333557, 2.286713, 
    1.982842, 1.888814, 1.847397, 1.814945, 1.783922, 1.754165, 1.734987, 
    1.712114, 1.685695, 1.666587, 1.649067, 1.630068, 1.608984, 1.599335, 
    1.578985, 1.556348
]
validation_loss = [
    3.7463, 3.4103, 3.0916, 3.0195, 2.7030, 2.5463, 2.5613, 2.4538, 2.6547, 
    2.4059, 2.3931, 2.1390, 2.2801, 2.0567, 1.6573, 1.6152, 1.5698, 1.5470, 
    1.5133, 1.5190, 1.4621, 1.5364, 1.5206, 1.4125, 1.4332, 1.3908, 1.4157, 
    1.4219, 1.3982, 1.3621
]

# Training and validation accuracy data
train_accuracy = [
    4.41, 8.41, 13.19, 17.27, 20.10, 22.25, 24.12, 26.57, 28.43, 30.58, 
    32.32, 33.17, 34.61, 35.90, 43.56, 45.91, 47.05, 47.84, 48.55, 49.27, 
    49.95, 50.42, 50.82, 51.89, 51.79, 52.59, 53.14, 53.50, 54.02, 54.45
]
validation_accuracy = [
    5.78, 10.22, 17.11, 20.00, 26.44, 30.44, 29.56, 32.89, 30.00, 34.22, 
    35.33, 38.00, 34.00, 41.78, 56.22, 54.67, 56.22, 55.11, 57.11, 57.11, 
    55.56, 55.78, 55.11, 57.11, 57.11, 58.67, 58.67, 57.78, 55.33, 58.44
]

# Creating the plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot for training and validation loss
ax1.plot(epochs, train_loss, 'cornflowerblue', label='Training Loss')
ax1.plot(epochs, validation_loss, 'plum', label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

# Plot for training and validation accuracy
ax2.plot(epochs, train_accuracy, 'cornflowerblue', label='Training Accuracy')
ax2.plot(epochs, validation_accuracy, 'plum', label='Validation Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

# plt.savefig('ResNet34_loss_accuracy_Plots.png', format='png', dpi=500)
# plt.close(fig)

plt.show()
